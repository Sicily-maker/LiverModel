# %% [markdown]
# ## extracting from recon3d

# %%
import os
import re
import warnings
from cobra.io.json import load_json_model as load_json_cobra_model
import escher
import mass
import numpy as np
import pandas as pd
import equilibrator_api
from equilibrator_api import ComponentContribution, Q_
import sympy as sym
from cobra import Model, Reaction, Metabolite
import cobra.test
from os.path import join
from mass.util import qcqa
from mass.util import qcqa_model
from cobra import DictList
from mass import (
    MassConfiguration, MassMetabolite, MassModel,
    MassReaction, Simulation, UnitDefinition)
from mass.io.json import save_json_model as save_json_mass_model
from mass.visualization import plot_comparison, plot_time_profile
from mass.visualization import (
    plot_ensemble_phase_portrait, plot_ensemble_time_profile)
mass_config = MassConfiguration()
mass_config.irreversible_Keq = float("inf")
print("MASSpy version: {0}".format(mass.__version__))
from six import iteritems
import matplotlib.pyplot as plt
from mass.thermo import (
    ConcSolver, sample_concentrations,
    update_model_with_concentration_solution)
from cobra.io.json import *
import cobra_dict as c_d
import csv
# Out:
# MASSpy version: 0.1.6

# %%
#load Recon3D
model_dir = os.path.abspath("models")
data_dir = os.path.abspath("data")
# model_dir
R3D=load_json_cobra_model(filename=os.path.join(model_dir,"Recon3D.json"))
glycolysis_ppp_tca_etc= load_json_cobra_model(filename=os.path.join(model_dir,"glycolysis_ppp_tca_etc_model.json"))
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-04-30

# %%
_REQUIRED_REACTION_ATTRIBUTES = [
    "id",
    "name",
    "metabolites",
    "lower_bound",
    "upper_bound",
#     "gene_reaction_rule",
]

_REQUIRED_METABOLITE_ATTRIBUTES = ["id", "name", "charge","formula", "compartment"]
_ORDERED_OPTIONAL_METABOLITE_KEYS = [
   
    "_bound",
    "notes",
    "annotation",
]

# %%
from cobra_dict import metabolite_to_dict as metabolite_to_dict
from cobra_dict import reaction_to_dict as reaction_to_dict

# %%
etc= [
    'FADH2ETC',
    'NADH2_u10mi',
    'CYOR_u10mi',
    'CYOOm2i',
    'MALtm',
    'AKGMALtm',
    'MDH',
    'ASPTA',
    'ASPGLUm',
    'ASPTAm',

]

# %%
reaction_list=[]
for rid in glycolysis_ppp_tca_etc.reactions:
    if rid.id in etc:
        reaction_list.append(rid.id)
len(reaction_list)
# Out:
# 10

# %%
metabolite_list=[]
for reaction in reaction_list:
    rxn = glycolysis_ppp_tca_etc.reactions.get_by_id(reaction)
    for met in rxn.metabolites:
        if met.id not in metabolite_list:
            metabolite_list.append(met.id)
len(metabolite_list)
# Out:
# 27

# %%
met_df=pd.DataFrame()
for met in metabolite_list:
    r3d_met= R3D.metabolites.get_by_id(met)
    m=metabolite_to_dict(r3d_met)
    df_2=pd.DataFrame.from_dict(m,orient='index')
    df_2=df_2.T
    met_df=met_df.append(df_2)

met_df=met_df.set_index('id')
met_df
# Out:
#                                                  name charge         formula  \
# id
# h_i                                                H+      0               H
# h_m                                                H+      0               H
# nad_m               Nicotinamide adenine dinucleotide     -1   C21H26N7O14P2
# nadh_m    Nicotinamide adenine dinucleotide - reduced     -2   C21H27N7O14P2
# q10_m                                   Ubiquinone-10      0        C59H90O4
# q10h2_m                                  Ubiquinol-10      0        C59H92O4
# fad_m            Flavin adenine dinucleotide oxidized     -2   C27H31N9O15P2
# fadh2_m           Flavin adenine dinucleotide reduced     -2   C27H33N9O15P2
# ficytC_m                            Ferricytochrome c      3  C42H54FeN8O6S2
# focytC_m                            Ferrocytochrome C      2  C42H54FeN8O6S2
# h2o_m                                         H2O H2O      0             H2O
# o2_m                                            O2 O2      0              O2
# mal__L_c                                     L-Malate     -2          C4H4O5
# mal__L_m                                     L-Malate     -2          C4H4O5
# pi_c                                        Phosphate      0            HO4P
# pi_m                                        Phosphate      0            HO4P
# h_c                                                H+      0               H
# nad_c               Nicotinamide adenine dinucleotide     -1   C21H26N7O14P2
# nadh_c    Nicotinamide adenine dinucleotide - reduced     -2   C21H27N7O14P2
# oaa_c                                    Oxaloacetate     -2          C4H2O5
# akg_c                                  2-Oxoglutarate     -2          C5H4O5
# akg_m                                  2-Oxoglutarate     -2          C5H4O5
# asp__L_c                                  L-Aspartate     -1         C4H6NO4
# glu__L_c                                  L-Glutamate     -1         C5H8NO4
# asp__L_m                                  L-Aspartate     -1         C4H6NO4
# glu__L_m                                  L-Glutamate     -1         C5H8NO4
# oaa_m                                    Oxaloacetate     -2          C4H2O5
#
#          compartment
# id
# h_i                i
# h_m                m
# nad_m              m
# nadh_m             m
# q10_m              m
# q10h2_m            m
# fad_m              m
# fadh2_m            m
# ficytC_m           m
# focytC_m           m
# h2o_m              m
# o2_m               m
# mal__L_c           c
# mal__L_m           m
# pi_c               c
# pi_m               m
# h_c                c
# nad_c              c
# nadh_c             c
# oaa_c              c
# akg_c              c
# akg_m              m
# asp__L_c           c
# glu__L_c           c
# asp__L_m           m
# glu__L_m           m
# oaa_m              m

# %%
csv_met = os.path.join(data_dir,"etc_met_df.csv")
met_df.to_csv(csv_met)

# %%
rxn_df=pd.DataFrame()
reactions_not_in_r3d=[]
for rxn in reaction_list:
    if rxn in R3D.reactions:
        r3d_rxn= R3D.reactions.get_by_id(rxn)
        r=reaction_to_dict(r3d_rxn)
    #     print(r)
        df=pd.DataFrame.from_dict(r,orient='index')
        df=df.T
        rxn_df=rxn_df.append(df)
    else:
        reactions_not_in_r3d.append(rxn)

rxn_df=rxn_df.set_index('id')
rxn_df
reactions_not_in_r3d
# Out:
# []

# %%
csv_rxn = os.path.join(data_dir,"etc_reaction_df.csv")
rxn_df.to_csv(csv_rxn)

# %%
json_rxn = os.path.join(data_dir,"etc_reaction_df.json")
rxn_df.to_json(json_rxn
,orient="index"
)
