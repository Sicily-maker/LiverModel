# %%
# normalized_df=(df-df.min())/(df.max()-df.min())
# normalized_df

# def absolute_maximum_scale(series):
#     if series.abs().min()!= 0:
#         series=series / series.abs().min()
#     else:
#         series= series / series.abs().max()
#     return series


# def absolute_maximum_scale(series):
#     return series / series.abs().max()

# def min_max_scaling(series):
#     return (series - series.min()) / (series.max() - series.min())

# for col in df.columns:
#     df[col] = min_max_scaling(df[col])

# print(df)

# column=df.iloc[:,2]
# vals = liscolumn.values
# # vals=vals/min_val
# max_val = vals / vals.abs().max()

# # vals=vals/max_val
# # df['STD'+ str(col)]=vals
# max_val
# for col in df.columns:
#     df[col] = absolute_maximum_scale(df[col])
# print(df)
# for col in range(len(df.columns)):
#     column=df.iloc[:,col]
#     vals = column.values
#     max_val = np.max(vals)
#     vals=vals/max_val
#     df['STD'+ str(col)]=vals




    # column=df.iloc[:,col]
    # vals=vals/min_val
    # max_val = np.max(vals)
    # print(max_val)

    # for col in range(len(df.columns)):
#     column=df.iloc[:,col]
#     vals=vals/min_val
#     max_val = np.max(vals)
#     print(max_val)
#     # vals=vals/max_val
#     # df['STD'+ str(col)]=vals

# df
